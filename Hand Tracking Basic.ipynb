# %%
from PIL import Image

# %% [markdown]
# # 카메라 실행

# %%
import cv2

cap = cv2.VideoCapture(0) # 0은 내부 카메라 1부터 외부 카메라

while True:
    success, img = cap.read()

    cv2.imshow("Image", img)
    cv2.waitKey(1)

# %%
img1 = Image.open("images\image1.jpg")
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=246x208 at 0x1A9F6E3E5C0>

# %% [markdown]
# # 프레임 표시

# %%
import cv2
import time

cap = cv2.VideoCapture(0)

pTime = 0
cTime = 0

while True:
    success, img = cap.read()

    ### 프레임 표시 ###
    cTime = time.time()
    fps = 1/(cTime - pTime)
    pTime = cTime

    cv2.putText(img, str(int(fps)), (10, 50), cv2.FONT_HERSHEY_PLAIN, 3, (255, 0, 255), 3)
    # (10,50)은 텍스트 위치 좌표 3, (255, 0 255), 3 은 순서대로 텍스트 크기, 색깔, 굵기
    ### 프레임 표시 ###

    cv2.imshow("Image", img)
    cv2.waitKey(1)

# %%
img2 = Image.open("images\image2.jpg")
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=246x208 at 0x1A9F71A3978>

# %% [markdown]
# # 손의 21개 특징점 표시

# %%
import cv2
import mediapipe as mp

cap = cv2.VideoCapture(0)

mpHands = mp.solutions.hands
hands = mpHands.Hands()
mpDraw = mp.solutions.drawing_utils

while True:
    success, img = cap.read()
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # RGB영상만 사용하기 때문에 RGB 형태로 변환해줘야 함
    results = hands.process(imgRGB)

    # 다수의 손을 검출하기 위한 루프
    if results.multi_hand_landmarks:
       for handLms in results.multi_hand_landmarks:
          mpDraw.draw_landmarks(img, handLms) # 손의 21개의 점을 표시

    cv2.imshow("Image", img)
    cv2.waitKey(1)

# %%
img3 = Image.open("images\image3.jpg")
img3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=246x208 at 0x1A9F71A3B70>

# %% [markdown]
# # 손의 21개 특징점 선으로 잇기

# %%
import cv2
import mediapipe as mp

cap = cv2.VideoCapture(0)

mpHands = mp.solutions.hands
hands = mpHands.Hands()
mpDraw = mp.solutions.drawing_utils

while True:
    success, img = cap.read()
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # RGB영상만 사용하기 때문에 RGB 형태로 변환해줘야 함
    results = hands.process(imgRGB)

    # 다수의 손을 검출하기 위한 루프
    if results.multi_hand_landmarks:
       for handLms in results.multi_hand_landmarks:
          mpDraw.draw_landmarks(img, handLms, mpHands.HAND_CONNECTIONS) # 손의 21개의 점을 선으로 이음

    cv2.imshow("Image", img)
    cv2.waitKey(1)

# %%
img4 = Image.open("images\image4.jpg")
img4
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=246x208 at 0x1A9F71A3D30>

# %% [markdown]
# # 손의 21개 ID와 x,y 좌표값 얻기

# %%
import cv2
import mediapipe as mp

cap = cv2.VideoCapture(0)

mpHands = mp.solutions.hands
hands = mpHands.Hands()
mpDraw = mp.solutions.drawing_utils

while True:
    success, img = cap.read()
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # RGB영상만 사용하기 때문에 RGB 형태로 변환해줘야 함
    results = hands.process(imgRGB)

    # 다수의 손을 검출하기 위한 루프
    if results.multi_hand_landmarks:
       for handLms in results.multi_hand_landmarks:
          for id, lm in enumerate(handLms.landmark):
              h, w, c = img.shape
              cx, cy = int(lm.x*w), int(lm.y*h)
              print(id, cx, cy) # 손 21개의 id 와 x,y 좌표
          mpDraw.draw_landmarks(img, handLms, mpHands.HAND_CONNECTIONS) # 손의 21개의 점을 선으로 이음

    cv2.imshow("Image", img)
    cv2.waitKey(1)

# %%
img7 = Image.open("images\image7.jpg")
img7
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=388x141 at 0x1106067E5C0>

# %%
img5 = Image.open("images\image5.jpg")
img5
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=66x262 at 0x11060580240>

# %% [markdown]
# # 손의 21개의 점 ID를 활용

# %%
import cv2
import mediapipe as mp

cap = cv2.VideoCapture(0)

mpHands = mp.solutions.hands
hands = mpHands.Hands()
mpDraw = mp.solutions.drawing_utils

while True:
    success, img = cap.read()
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # RGB영상만 사용하기 때문에 RGB 형태로 변환해줘야 함
    results = hands.process(imgRGB)

    # 다수의 손을 검출하기 위한 루프
    if results.multi_hand_landmarks:
       for handLms in results.multi_hand_landmarks:
          for id, lm in enumerate(handLms.landmark):
              h, w, c = img.shape
              cx, cy = int(lm.x*w), int(lm.y*h)
              if id == 0:
                  cv2.circle(img, (cx, cy), 15, (255, 0,255), cv2.FILLED) # ID == 0인 곳에 원 출력
          mpDraw.draw_landmarks(img, handLms, mpHands.HAND_CONNECTIONS) # 손의 21개의 점을 선으로 이음

    cv2.imshow("Image", img)
    cv2.waitKey(1)

# %%
img6 = Image.open("images\image6.jpg")
img6
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=246x208 at 0x11060665908>
